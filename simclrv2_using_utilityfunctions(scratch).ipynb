# %% [markdown]
# <a href="https://colab.research.google.com/github/SruthiChilukuri/advanced_deep_learning/blob/master/simclrv2_using_utilityfunctions(scratch).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.manifold import TSNE
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from wandb.keras import WandbCallback
import matplotlib.pyplot as plt
from imutils import paths
from tqdm import tqdm
import tensorflow as tf
import seaborn as sns
import numpy as np
import cv2
# Random seed fixation
tf.random.set_seed(666)
np.random.seed(666)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
# !nvidia-smi
# Out:
# Sun Sep 27 03:20:56 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install --upgrade https://github.com/wandb/client/archive/feature/code-save.zip
# Out:
# Collecting https://github.com/wandb/client/archive/feature/code-save.zip
#   Downloading https://github.com/wandb/client/archive/feature/code-save.zip
#      - 19.5MB 10.3MB/s
# Requirement already satisfied, skipping upgrade: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from wandb==0.8.36) (7.1.2)
# Collecting GitPython>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/09/bc/ae32e07e89cc25b9e5c793d19a1e5454d30a8e37d95040991160f942519e/GitPython-3.1.8-py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 4.7MB/s
# Collecting gql==0.2.0
#   Downloading https://files.pythonhosted.org/packages/c4/6f/cf9a3056045518f06184e804bae89390eb706168349daa9dff8ac609962a/gql-0.2.0.tar.gz
# Requirement already satisfied, skipping upgrade: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.6/dist-packages (from wandb==0.8.36) (7.352.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from wandb==0.8.36) (2.8.1)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb==0.8.36) (2.23.0)
# Collecting shortuuid>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/25/a6/2ecc1daa6a304e7f1b216f0896b26156b78e7c38e1211e9b798b4716c53d/shortuuid-1.0.1-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from wandb==0.8.36) (1.15.0)
# Collecting watchdog>=0.8.3
#   Downloading https://files.pythonhosted.org/packages/0e/06/121302598a4fc01aca942d937f4a2c33430b7181137b35758913a8db10ad/watchdog-0.10.3.tar.gz (94kB)
#      |████████████████████████████████| 102kB 9.8MB/s
# Requirement already satisfied, skipping upgrade: PyYAML>=3.10 in /usr/local/lib/python3.6/dist-packages (from wandb==0.8.36) (3.13)
# Requirement already satisfied, skipping upgrade: psutil>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb==0.8.36) (5.4.8)
# Collecting sentry-sdk>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/6f/0f/fabe13834484d499064198f8ecf6904a4ce569246ce41d2d747432a8f3c8/sentry_sdk-0.17.8-py2.py3-none-any.whl (120kB)
#      |████████████████████████████████| 122kB 15.1MB/s
# Collecting subprocess32>=3.5.3
#   Downloading https://files.pythonhosted.org/packages/32/c8/564be4d12629b912ea431f1a50eb8b3b9d00f1a0b1ceff17f266be190007/subprocess32-3.5.4.tar.gz (97kB)
#      |████████████████████████████████| 102kB 9.3MB/s
# Collecting docker-pycreds>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Collecting configparser>=3.8.1
#   Downloading https://files.pythonhosted.org/packages/4b/6b/01baa293090240cf0562cc5eccb69c6f5006282127f2b846fad011305c79/configparser-5.0.0-py3-none-any.whl
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 8.5MB/s
# Collecting graphql-core<2,>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/b0/89/00ad5e07524d8c523b14d70c685e0299a8b0de6d0727e368c41b89b7ed0b/graphql-core-1.1.tar.gz (70kB)
#      |████████████████████████████████| 71kB 7.8MB/s
# Requirement already satisfied, skipping upgrade: promise<3,>=2.0 in /usr/local/lib/python3.6/dist-packages (from gql==0.2.0->wandb==0.8.36) (2.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb==0.8.36) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb==0.8.36) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb==0.8.36) (2020.6.20)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb==0.8.36) (3.0.4)
# Collecting pathtools>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/e7/7f/470d6fcdf23f9f3518f6b0b76be9df16dcc8630ad409947f8be2eb0ed13a/pathtools-0.1.2.tar.gz
# Collecting smmap<4,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/b0/9a/4d409a6234eb940e6a78dfdfc66156e7522262f5f2fecca07dc55915952d/smmap-3.0.4-py2.py3-none-any.whl
# Building wheels for collected packages: wandb, gql, watchdog, subprocess32, graphql-core, pathtools
#   Building wheel for wandb (setup.py) ... done
#   Created wheel for wandb: filename=wandb-0.8.36-py2.py3-none-any.whl size=1385041 sha256=a0b2e23751a83a36ef5ddd7ca09b32ad6ab8f5a06bf29deb2fc83529cb1ec43c
#   Stored in directory: /root/.cache/pip/wheels/6e/96/54/f4aafa18d112d4c6e313ac393b3b85513d090dd15b37357f19
#   Building wheel for gql (setup.py) ... done
#   Created wheel for gql: filename=gql-0.2.0-cp36-none-any.whl size=7630 sha256=80430a5c579d6969b773981571c127c71eabf1cddb4b4ae91b5588ae8d13180a
#   Stored in directory: /root/.cache/pip/wheels/ce/0e/7b/58a8a5268655b3ad74feef5aa97946f0addafb3cbb6bd2da23
#   Building wheel for watchdog (setup.py) ... done
#   Created wheel for watchdog: filename=watchdog-0.10.3-cp36-none-any.whl size=73873 sha256=d388f225c569200d8445d0bd233303f1d2d05e5fee60965055fe1e52ea90edea
#   Stored in directory: /root/.cache/pip/wheels/a8/1d/38/2c19bb311f67cc7b4d07a2ec5ea36ab1a0a0ea50db994a5bc7
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-cp36-none-any.whl size=6489 sha256=9428280157c23e906f757cde259acc9e7781c62b3a3a920ae0f3d404e5765215
#   Stored in directory: /root/.cache/pip/wheels/68/39/1a/5e402bdfdf004af1786c8b853fd92f8c4a04f22aad179654d1
#   Building wheel for graphql-core (setup.py) ... done
#   Created wheel for graphql-core: filename=graphql_core-1.1-cp36-none-any.whl size=104651 sha256=1fd437abac26f35a3239641fdf7049a0d9dda545841b81481ccfd0c32758468f
#   Stored in directory: /root/.cache/pip/wheels/45/99/d7/c424029bb0fe910c63b68dbf2aa20d3283d023042521bcd7d5
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-cp36-none-any.whl size=8785 sha256=57ccbef26f113cd58a3a63b3e7c0cef4d8ddedd652cf1f21dfb75e65d6272855
#   Stored in directory: /root/.cache/pip/wheels/0b/04/79/c3b0c3a0266a3cb4376da31e5bfe8bba0c489246968a68e843
# Successfully built wandb gql watchdog subprocess32 graphql-core pathtools
# Installing collected packages: smmap, gitdb, GitPython, graphql-core, gql, shortuuid, pathtools, watchdog, sentry-sdk, subprocess32, docker-pycreds, configparser, wandb
# Successfully installed GitPython-3.1.8 configparser-5.0.0 docker-pycreds-0.4.0 gitdb-4.0.5 gql-0.2.0 graphql-core-1.1 pathtools-0.1.2 sentry-sdk-0.17.8 shortuuid-1.0.1 smmap-3.0.4 subprocess32-3.5.4 wandb-0.8.36 watchdog-0.10.3

# %%
import wandb
wandb.login()
# Out:
# wandb: ERROR Not authenticated.  Copy a key from https://app.wandb.ai/authorize
# API Key: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
from google.colab import auth
auth.authenticate_user()
PROJECT_ID = "fast-ai-exploration" 
# !gcloud config set project $PROJECT_ID
# Out:
# Updated property [core/project].
# WARNING: You do not appear to have access to project [fast-ai-exploration] or it does not exist.

# %%
# !gsutil cp gs://resnet_simclr_imagenet/20200508-134915resnet_simclr.h5 .
# Out:
# AccessDeniedException: 403 srisruthi.chilukuri@sjsu.edu does not have storage.objects.list access to the Google Cloud Storage bucket.

# %%
simclr_weights = wandb.restore("20200509-042927resnet_simclr.h5", run_path="sayakpaul/simclr/simclr-learning")

# %%
# !git clone https://github.com/thunderInfy/imagenet-5-categories
# Out:
# Cloning into 'imagenet-5-categories'...
# remote: Enumerating objects: 1532, done.
# remote: Total 1532 (delta 0), reused 0 (delta 0), pack-reused 1532
# Receiving objects: 100% (1532/1532), 88.56 MiB | 48.83 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
train_images = list(paths.list_images("imagenet-5-categories/train"))
test_images = list(paths.list_images("imagenet-5-categories/test"))
print(len(train_images), len(test_images))
# Out:
# 1250 250

# %%
train_images_10 = np.random.choice(train_images, len(train_images)//10)
len(train_images_10)
# Out:
# 125

# %%
def prepare_images(image_paths):
    images = []
    labels = []

    for image in tqdm(image_paths):
        image_pixels = plt.imread(image)
        image_pixels = cv2.resize(image_pixels, (224, 224))
        image_pixels = image_pixels/255.

        label = image.split("/")[2].split("_")[0]

        images.append(image_pixels)
        labels.append(label)

    images = np.array(images)
    labels = np.array(labels)

    print(images.shape, labels.shape)

    return images, labels

# %%
X_train, y_train = prepare_images(train_images_10)
X_test, y_test = prepare_images(test_images)
# Out:
# 100%|██████████| 125/125 [00:00<00:00, 203.28it/s]
#  10%|█         | 25/250 [00:00<00:00, 247.61it/s]
# (125, 224, 224, 3) (125,)
# 100%|██████████| 250/250 [00:01<00:00, 212.84it/s]
# (250, 224, 224, 3) (250,)

# %%
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_test_enc = le.transform(y_test)

# %%
def get_resnet_simclr(hidden_1, hidden_2, hidden_3):
    base_model = tf.keras.applications.ResNet50(include_top=False, weights=None, input_shape=(224, 224, 3))
    base_model.trainable = True
    inputs = Input((224, 224, 3))
    h = base_model(inputs, training=False)
    h = GlobalAveragePooling2D()(h)

    projection_1 = Dense(hidden_1)(h)
    projection_1 = Activation("relu")(projection_1)
    projection_2 = Dense(hidden_2)(projection_1)
    projection_2 = Activation("relu")(projection_2)
    projection_3 = Dense(hidden_3)(projection_2)

    resnet_simclr = Model(inputs, projection_3)

    return resnet_simclr

# %%
resnet_simclr = get_resnet_simclr(256, 128, 50)
resnet_simclr.load_weights(simclr_weights.name)
resnet_simclr.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                6450
# =================================================================
# Total params: 24,151,602
# Trainable params: 24,098,482
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
def plot_training(H):
  with plt.xkcd():
		  plt.plot(H.history["loss"], label="train_loss")
		  plt.plot(H.history["val_loss"], label="val_loss")
		  plt.plot(H.history["accuracy"], label="train_acc")
		  plt.plot(H.history["val_accuracy"], label="val_acc")
		  plt.title("Training Loss and Accuracy")
		  plt.xlabel("Epoch #")
		  plt.ylabel("Loss/Accuracy")
		  plt.legend(loc="lower left")
		  plt.show()

# %%
def get_linear_model(features):
    linear_model = Sequential([Dense(5, input_shape=(features, ), activation="softmax")])
    return linear_model

# %%
resnet_simclr.layers[1].trainable = False
resnet_simclr.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                6450
# =================================================================
# Total params: 24,151,602
# Trainable params: 563,890
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
# Encoder model with non-linear projections
projection = Model(resnet_simclr.input, resnet_simclr.layers[-2].output)
# Extract train and test features
train_features = projection.predict(X_train)
test_features = projection.predict(X_test)
print(train_features.shape, test_features.shape)
# Out:
# (125, 128) (250, 128)

# %%
es = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=2, verbose=2, restore_best_weights=True)

# %%
wandb.init(project="simclr", id="linear-eval-relu-last")

linear_model = get_linear_model(128)
linear_model.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"],
                     optimizer="adam")
history = linear_model.fit(train_features, y_train_enc,
                 validation_data=(test_features, y_test_enc),
                 batch_size=64,
                 epochs=35,
                 callbacks=[es, WandbCallback()])
plot_training(history)
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/sruthi_ch/simclr" target="_blank">https://app.wandb.ai/sruthi_ch/simclr</a><br/>
#                 Run page: <a href="https://app.wandb.ai/sruthi_ch/simclr/runs/linear-eval-relu-last" target="_blank">https://app.wandb.ai/sruthi_ch/simclr/runs/linear-eval-relu-last</a><br/>
# wandb: Wandb version 0.10.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# Epoch 1/35
# 2/2 [==============================] - 0s 84ms/step - loss: 3.3724 - accuracy: 0.1680 - val_loss: 3.1350 - val_accuracy: 0.1720
# Epoch 2/35
# 2/2 [==============================] - 0s 24ms/step - loss: 3.1815 - accuracy: 0.1600 - val_loss: 2.9783 - val_accuracy: 0.1800
# Epoch 3/35
# 2/2 [==============================] - 0s 21ms/step - loss: 3.0161 - accuracy: 0.1920 - val_loss: 2.8328 - val_accuracy: 0.2160
# Epoch 4/35
# 2/2 [==============================] - 0s 22ms/step - loss: 2.8594 - accuracy: 0.1920 - val_loss: 2.7004 - val_accuracy: 0.2320
# Epoch 5/35
# 2/2 [==============================] - 0s 22ms/step - loss: 2.7196 - accuracy: 0.2000 - val_loss: 2.5794 - val_accuracy: 0.2320
# Epoch 6/35
# 2/2 [==============================] - 0s 23ms/step - loss: 2.5859 - accuracy: 0.2000 - val_loss: 2.4737 - val_accuracy: 0.2400
# Epoch 7/35
# 2/2 [==============================] - 0s 23ms/step - loss: 2.4669 - accuracy: 0.2240 - val_loss: 2.3792 - val_accuracy: 0.2640
# Epoch 8/35
# 2/2 [==============================] - 0s 24ms/step - loss: 2.3598 - accuracy: 0.2400 - val_loss: 2.2965 - val_accuracy: 0.2840
# Epoch 9/35
# 2/2 [==============================] - 0s 29ms/step - loss: 2.2546 - accuracy: 0.2400 - val_loss: 2.2225 - val_accuracy: 0.3000
# Epoch 10/35
# 2/2 [==============================] - 0s 25ms/step - loss: 2.1607 - accuracy: 0.2640 - val_loss: 2.1560 - val_accuracy: 0.3120
# Epoch 11/35
# 2/2 [==============================] - 0s 23ms/step - loss: 2.0757 - accuracy: 0.2880 - val_loss: 2.0945 - val_accuracy: 0.3440
# Epoch 12/35
# 2/2 [==============================] - 0s 26ms/step - loss: 1.9955 - accuracy: 0.3040 - val_loss: 2.0381 - val_accuracy: 0.3600
# Epoch 13/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.9196 - accuracy: 0.3120 - val_loss: 1.9855 - val_accuracy: 0.3600
# Epoch 14/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.8515 - accuracy: 0.3440 - val_loss: 1.9378 - val_accuracy: 0.3720
# Epoch 15/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.7886 - accuracy: 0.3760 - val_loss: 1.8931 - val_accuracy: 0.3880
# Epoch 16/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.7249 - accuracy: 0.3760 - val_loss: 1.8520 - val_accuracy: 0.4000
# Epoch 17/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.6707 - accuracy: 0.4000 - val_loss: 1.8136 - val_accuracy: 0.4120
# Epoch 18/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.6187 - accuracy: 0.4160 - val_loss: 1.7779 - val_accuracy: 0.4200
# Epoch 19/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.5743 - accuracy: 0.4320 - val_loss: 1.7451 - val_accuracy: 0.4200
# Epoch 20/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.5308 - accuracy: 0.4320 - val_loss: 1.7149 - val_accuracy: 0.4160
# Epoch 21/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.4912 - accuracy: 0.4400 - val_loss: 1.6882 - val_accuracy: 0.4240
# Epoch 22/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.4553 - accuracy: 0.4640 - val_loss: 1.6634 - val_accuracy: 0.4240
# Epoch 23/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.4205 - accuracy: 0.4640 - val_loss: 1.6408 - val_accuracy: 0.4280
# Epoch 24/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.3900 - accuracy: 0.4720 - val_loss: 1.6202 - val_accuracy: 0.4240
# Epoch 25/35
# 2/2 [==============================] - 0s 27ms/step - loss: 1.3602 - accuracy: 0.4800 - val_loss: 1.6020 - val_accuracy: 0.4280
# Epoch 26/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.3349 - accuracy: 0.4880 - val_loss: 1.5851 - val_accuracy: 0.4280
# Epoch 27/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.3103 - accuracy: 0.4960 - val_loss: 1.5699 - val_accuracy: 0.4240
# Epoch 28/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.2862 - accuracy: 0.5120 - val_loss: 1.5557 - val_accuracy: 0.4200
# Epoch 29/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.2655 - accuracy: 0.5120 - val_loss: 1.5430 - val_accuracy: 0.4240
# Epoch 30/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.2452 - accuracy: 0.5200 - val_loss: 1.5314 - val_accuracy: 0.4280
# Epoch 31/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.2253 - accuracy: 0.5280 - val_loss: 1.5202 - val_accuracy: 0.4360
# Epoch 32/35
# 2/2 [==============================] - 0s 27ms/step - loss: 1.2071 - accuracy: 0.5200 - val_loss: 1.5100 - val_accuracy: 0.4360
# Epoch 33/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.1898 - accuracy: 0.5200 - val_loss: 1.5004 - val_accuracy: 0.4360
# Epoch 34/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.1731 - accuracy: 0.5280 - val_loss: 1.4919 - val_accuracy: 0.4440
# Epoch 35/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.1580 - accuracy: 0.5360 - val_loss: 1.4843 - val_accuracy: 0.4440

# %%
projection = Model(resnet_simclr.input, resnet_simclr.layers[-4].output)
train_features = projection.predict(X_train)
test_features = projection.predict(X_test)
print(train_features.shape, test_features.shape)
# Out:
# (125, 256) (250, 256)

# %%
wandb.init(project="simclr", id="linear-eval-relu-second-last")
linear_model = get_linear_model(256)
linear_model.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"],
                     optimizer="adam")
history = linear_model.fit(train_features, y_train_enc,
                 validation_data=(test_features, y_test_enc),
                 batch_size=64,
                 epochs=35,
                 callbacks=[es, WandbCallback()])
plot_training(history)
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/sruthi_ch/simclr" target="_blank">https://app.wandb.ai/sruthi_ch/simclr</a><br/>
#                 Run page: <a href="https://app.wandb.ai/sruthi_ch/simclr/runs/linear-eval-relu-second-last" target="_blank">https://app.wandb.ai/sruthi_ch/simclr/runs/linear-eval-relu-second-last</a><br/>
# wandb: Wandb version 0.10.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# Epoch 1/35
# 2/2 [==============================] - 0s 71ms/step - loss: 4.0213 - accuracy: 0.2640 - val_loss: 3.3661 - val_accuracy: 0.3000
# Epoch 2/35
# 2/2 [==============================] - 0s 28ms/step - loss: 3.4897 - accuracy: 0.2560 - val_loss: 2.9623 - val_accuracy: 0.3280
# Epoch 3/35
# 2/2 [==============================] - 0s 27ms/step - loss: 3.1133 - accuracy: 0.3120 - val_loss: 2.6775 - val_accuracy: 0.3040
# Epoch 4/35
# 2/2 [==============================] - 0s 25ms/step - loss: 2.8062 - accuracy: 0.3120 - val_loss: 2.4585 - val_accuracy: 0.3320
# Epoch 5/35
# 2/2 [==============================] - 0s 24ms/step - loss: 2.5482 - accuracy: 0.3200 - val_loss: 2.2712 - val_accuracy: 0.3320
# Epoch 6/35
# 2/2 [==============================] - 0s 24ms/step - loss: 2.3196 - accuracy: 0.3280 - val_loss: 2.1227 - val_accuracy: 0.3240
# Epoch 7/35
# 2/2 [==============================] - 0s 31ms/step - loss: 2.1493 - accuracy: 0.3520 - val_loss: 2.0059 - val_accuracy: 0.3280
# Epoch 8/35
# 2/2 [==============================] - 0s 27ms/step - loss: 1.9888 - accuracy: 0.3680 - val_loss: 1.9276 - val_accuracy: 0.3400
# Epoch 9/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.8547 - accuracy: 0.3600 - val_loss: 1.8746 - val_accuracy: 0.3400
# Epoch 10/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.7482 - accuracy: 0.3680 - val_loss: 1.8366 - val_accuracy: 0.3520
# Epoch 11/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.6802 - accuracy: 0.3600 - val_loss: 1.8042 - val_accuracy: 0.3520
# Epoch 12/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.6147 - accuracy: 0.4000 - val_loss: 1.7612 - val_accuracy: 0.3680
# Epoch 13/35
# 2/2 [==============================] - 0s 28ms/step - loss: 1.5531 - accuracy: 0.4000 - val_loss: 1.7033 - val_accuracy: 0.3760
# Epoch 14/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.4830 - accuracy: 0.4080 - val_loss: 1.6386 - val_accuracy: 0.3920
# Epoch 15/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.4099 - accuracy: 0.4720 - val_loss: 1.5745 - val_accuracy: 0.4280
# Epoch 16/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.3571 - accuracy: 0.5040 - val_loss: 1.5112 - val_accuracy: 0.4520
# Epoch 17/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.2979 - accuracy: 0.5360 - val_loss: 1.4674 - val_accuracy: 0.4720
# Epoch 18/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.2538 - accuracy: 0.5200 - val_loss: 1.4334 - val_accuracy: 0.4840
# Epoch 19/35
# 2/2 [==============================] - 0s 26ms/step - loss: 1.2154 - accuracy: 0.5040 - val_loss: 1.4121 - val_accuracy: 0.4720
# Epoch 20/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.1860 - accuracy: 0.5120 - val_loss: 1.3963 - val_accuracy: 0.4600
# Epoch 21/35
# 2/2 [==============================] - 0s 22ms/step - loss: 1.1639 - accuracy: 0.5040 - val_loss: 1.3865 - val_accuracy: 0.4600
# Epoch 22/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.1376 - accuracy: 0.5120 - val_loss: 1.3785 - val_accuracy: 0.4720
# Epoch 23/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.1144 - accuracy: 0.5120 - val_loss: 1.3688 - val_accuracy: 0.4760
# Epoch 24/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.0926 - accuracy: 0.5200 - val_loss: 1.3591 - val_accuracy: 0.4720
# Epoch 25/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.0702 - accuracy: 0.5360 - val_loss: 1.3499 - val_accuracy: 0.4800
# Epoch 26/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.0553 - accuracy: 0.5600 - val_loss: 1.3405 - val_accuracy: 0.4960
# Epoch 27/35
# 2/2 [==============================] - 0s 22ms/step - loss: 1.0425 - accuracy: 0.5520 - val_loss: 1.3317 - val_accuracy: 0.5040
# Epoch 28/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.0263 - accuracy: 0.5520 - val_loss: 1.3185 - val_accuracy: 0.5120
# Epoch 29/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.0138 - accuracy: 0.5440 - val_loss: 1.3065 - val_accuracy: 0.5040
# Epoch 30/35
# 2/2 [==============================] - 0s 26ms/step - loss: 1.0009 - accuracy: 0.5440 - val_loss: 1.2959 - val_accuracy: 0.5120
# Epoch 31/35
# 2/2 [==============================] - 0s 28ms/step - loss: 0.9902 - accuracy: 0.5440 - val_loss: 1.2858 - val_accuracy: 0.5000
# Epoch 32/35
# 2/2 [==============================] - 0s 23ms/step - loss: 0.9795 - accuracy: 0.5440 - val_loss: 1.2788 - val_accuracy: 0.4880
# Epoch 33/35
# 2/2 [==============================] - 0s 24ms/step - loss: 0.9710 - accuracy: 0.5520 - val_loss: 1.2722 - val_accuracy: 0.4960
# Epoch 34/35
# 2/2 [==============================] - 0s 25ms/step - loss: 0.9622 - accuracy: 0.5440 - val_loss: 1.2698 - val_accuracy: 0.4960
# Epoch 35/35
# 2/2 [==============================] - 0s 24ms/step - loss: 0.9570 - accuracy: 0.5600 - val_loss: 1.2688 - val_accuracy: 0.5080

# %%
projection = Model(resnet_simclr.input, resnet_simclr.layers[-6].output)
train_features = projection.predict(X_train)
test_features = projection.predict(X_test)
print(train_features.shape, test_features.shape)
# Out:
# (125, 2048) (250, 2048)

# %%
wandb.init(project="simclr", id="linear-eval-no-projections")
linear_model = get_linear_model(2048)
linear_model.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"],
                     optimizer="adam")
history = linear_model.fit(train_features, y_train_enc,
                 validation_data=(test_features, y_test_enc),
                 batch_size=64,
                 epochs=35,
                 callbacks=[es, WandbCallback()])
plot_training(history)
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/sruthi_ch/simclr" target="_blank">https://app.wandb.ai/sruthi_ch/simclr</a><br/>
#                 Run page: <a href="https://app.wandb.ai/sruthi_ch/simclr/runs/linear-eval-no-projections" target="_blank">https://app.wandb.ai/sruthi_ch/simclr/runs/linear-eval-no-projections</a><br/>
# wandb: Wandb version 0.10.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# Epoch 1/35
# 2/2 [==============================] - 0s 64ms/step - loss: 3.0755 - accuracy: 0.1440 - val_loss: 2.4603 - val_accuracy: 0.0840
# Epoch 2/35
# 2/2 [==============================] - 0s 26ms/step - loss: 2.2124 - accuracy: 0.1600 - val_loss: 2.0175 - val_accuracy: 0.2240
# Epoch 3/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.8621 - accuracy: 0.2320 - val_loss: 1.7975 - val_accuracy: 0.2240
# Epoch 4/35
# 2/2 [==============================] - 0s 26ms/step - loss: 1.5169 - accuracy: 0.3280 - val_loss: 1.3798 - val_accuracy: 0.4760
# Epoch 5/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.3150 - accuracy: 0.4400 - val_loss: 1.3169 - val_accuracy: 0.5120
# Epoch 6/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.2284 - accuracy: 0.5200 - val_loss: 1.2450 - val_accuracy: 0.5320
# Epoch 7/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.1217 - accuracy: 0.5440 - val_loss: 1.2004 - val_accuracy: 0.5640
# Epoch 8/35
# 2/2 [==============================] - 0s 18ms/step - loss: 1.0419 - accuracy: 0.5680 - val_loss: 1.2622 - val_accuracy: 0.4840
# Epoch 9/35
# 1/2 [==============>...............] - ETA: 0s - loss: 0.9685 - accuracy: 0.6250Restoring model weights from the end of the best epoch.
# 2/2 [==============================] - 0s 20ms/step - loss: 1.0368 - accuracy: 0.5840 - val_loss: 1.2413 - val_accuracy: 0.5560
# Epoch 00009: early stopping

# %%
wandb.init(project="simclr", id="visualization")
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/sruthi_ch/simclr" target="_blank">https://app.wandb.ai/sruthi_ch/simclr</a><br/>
#                 Run page: <a href="https://app.wandb.ai/sruthi_ch/simclr/runs/visualization" target="_blank">https://app.wandb.ai/sruthi_ch/simclr/runs/visualization</a><br/>
# wandb: Wandb version 0.10.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# W&B Run: https://app.wandb.ai/sruthi_ch/simclr/runs/visualization

# %%
def plot_vecs_n_labels(v, labels):
    fig = plt.figure(figsize = (10, 10))
    sns.set_style("darkgrid")
    sns.scatterplot(v[:,0], v[:,1], hue=labels, legend='full', palette=sns.color_palette("bright", 5))
    plt.show()

    return fig

# %%
tsne = TSNE()
low_vectors = tsne.fit_transform(train_features)
fig = plot_vecs_n_labels(low_vectors, y_train_enc)
wandb.log({"no_no_linear_projection": fig})
# Out:
# wandb: Wandb version 0.10.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# /usr/local/lib/python3.6/dist-packages/plotly/matplotlylib/mpltools.py:368: MatplotlibDeprecationWarning:
#
#
# The is_frame_like function was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#
# /usr/local/lib/python3.6/dist-packages/plotly/matplotlylib/renderer.py:474: UserWarning:
#
# Dang! That path collection is out of this world. I totally don't know what to do with it yet! Plotly can only import path collections linked to 'data' coordinates
#
# /usr/local/lib/python3.6/dist-packages/plotly/matplotlylib/renderer.py:512: UserWarning:
#
# I found a path object that I don't think is part of a bar chart. Ignoring.

# %%
tsne = TSNE()
projection = Model(resnet_simclr.input, resnet_simclr.layers[-2].output)
train_features = projection.predict(X_train)
low_vectors = tsne.fit_transform(train_features)
fig = plot_vecs_n_labels(low_vectors, y_train_enc)
wandb.log({"last_relu": fig})
# Out:
# wandb: Wandb version 0.10.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# /usr/local/lib/python3.6/dist-packages/plotly/matplotlylib/mpltools.py:368: MatplotlibDeprecationWarning:
#
#
# The is_frame_like function was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#
# /usr/local/lib/python3.6/dist-packages/plotly/matplotlylib/renderer.py:474: UserWarning:
#
# Dang! That path collection is out of this world. I totally don't know what to do with it yet! Plotly can only import path collections linked to 'data' coordinates
#
# /usr/local/lib/python3.6/dist-packages/plotly/matplotlylib/renderer.py:512: UserWarning:
#
# I found a path object that I don't think is part of a bar chart. Ignoring.
